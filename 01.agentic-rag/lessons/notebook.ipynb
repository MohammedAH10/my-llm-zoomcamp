# %% [markdown]
# Starting jupyter server via `uv`
#
#
# `uv run jupyter notebook`

# %%
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()

open_ai_client = OpenAI()

# %% [markdown]
# For Groq and other OpenAI compatible providers

# %%
# GROQ_API_KEY

from openai import OpenAI
import os 

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %% [markdown]
# Auto-loading .env with dirdotenv
#
# If you don't want to call load_dotenv() in every notebook, use dirdotenv.
#
# It loads .env files automatically when you cd into a directory:

# %% [markdown]
# uv tool install dirdotenv
# echo 'eval "$(dirdotenv hook bash)"' >> ~/.bashrc
